# %%
pip install pandas-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.9/345.9 kB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 86.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.8/679.8 kB 48.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 90.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pandas_profiling
import numpy as np

#importing the data
df = pd.read_csv('/content/linkedin_data.csv',encoding='ISO-8859-1')
# Out:
# <ipython-input-2-e0c848fb0815>:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
df.head()
# Out:
#         Date                                           Job_Name  \
# 0  3/31/2023  Client Technology: Platform Engineering, Senio...
# 1  3/31/2023  Associate  Global Intelligence (Open Source Co...
# 2  3/31/2023                      MTS Software Development Eng.
# 3  3/31/2023                        Tech Lead  Wifi Development
# 4  3/31/2023                      Senior Application Specialist
#
#                 Company    Location         State Country Job_type  \
# 0                    EY  Trivandrum        Kerala   India   Onsite
# 1  JPMorgan Chase & Co.      Mumbai   Maharashtra   India   Onsite
# 2                   AMD   Bengaluru     Karnataka   India   Onsite
# 3     VVDN Technologies     Chennai    Tamil Nadu   India   Onsite
# 4      Leica Biosystems      Mumbai   Maharashtra   India   Onsite
#
#    Employees_Avg  Followers_Numbers  New Applicants  \
# 0          10001            7366377               9
# 1          10001            3791093              10
# ...

# %%
df.describe()
# Out:
#        Employees_Avg  Followers_Numbers  New Applicants
# count    1127.000000       1.127000e+03     1127.000000
# mean     5831.957409       1.226621e+06       77.096717
# std      4387.291134       2.365715e+06       66.734492
# min         6.000000       3.000000e+00        1.000000
# 25%       750.000000       2.848750e+04       21.000000
# 50%      7500.000000       1.988420e+05       56.000000
# 75%     10001.000000       1.317948e+06      118.000000
# max     10001.000000       1.519667e+07      200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1127 entries, 0 to 1126
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1127 non-null   object
#  1   Job_Name           1127 non-null   object
#  2   Company            1127 non-null   object
#  3   Location           1127 non-null   object
#  4   State              1127 non-null   object
#  5   Country            1127 non-null   object
#  6   Job_type           1127 non-null   object
#  7   Employees_Avg      1127 non-null   int64
#  8   Followers_Numbers  1127 non-null   int64
#  9   New Applicants     1127 non-null   int64
#  10  Industry           1127 non-null   object
#  11  Invovlement        1127 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 105.8+ KB

# %%
df.isnull().sum()
# Out:
# Date                 0
# Job_Name             0
# Company              0
# Location             0
# State                0
# Country              0
# Job_type             0
# Employees_Avg        0
# Followers_Numbers    0
# New Applicants       0
# Industry             0
# Invovlement          0
# dtype: int64

# %%
df1=df.drop('Date',axis=1)

# %%
order={'Job_type':{'Onsite':1,'Hybrid':2,'Remote':3}}

# %%
df1=df1.replace(order)

# %%
df1
# Out:
#                                                Job_Name               Company  \
# 0     Client Technology: Platform Engineering, Senio...                    EY
# 1     Associate  Global Intelligence (Open Source Co...  JPMorgan Chase & Co.
# 2                         MTS Software Development Eng.                   AMD
# 3                           Tech Lead  Wifi Development     VVDN Technologies
# 4                         Senior Application Specialist      Leica Biosystems
# ...                                                 ...                   ...
# 1122                              AM AnalyticsANA007048               Genpact
# 1123                       Senior Data & API Consultant           Pluralsight
# 1124                                              Staff                 Bunge
# 1125      Software Performance Analyst (Cyber Security)            BlackBerry
# 1126                                  Team LeadBig Data              Infogain
#
# ...

# %%
df1.columns
# Out:
# Index(['Job_Name', 'Company', 'Location', 'State', 'Country', 'Job_type',
#        'Employees_Avg', 'Followers_Numbers', 'New Applicants', 'Industry',
#        'Invovlement'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
# Plot the distribution of employees
plt.hist(df1['Employees_Avg'])
plt.xlabel('Employees_Avg ')
plt.ylabel('Frequency')
plt.title('Distribution of Employees')
plt.show()

# %%
# Plot the distribution of followers
plt.hist(df1['Followers_Numbers'])
plt.xlabel('Followers_Numbers')
plt.ylabel('Frequency')
plt.title('Distribution of Followers')
plt.show()

# %%
# Count the number of job types
jobtype_count = df1['Job_type'].value_counts()
print(jobtype_count)
# Out:
# 1    725
# 2    345
# 3     57
# Name: Job_type, dtype: int64

# %%
# Plot the job type counts
plt.bar(jobtype_count.index, jobtype_count.values)
plt.xlabel('job Type')
plt.ylabel('Count')
plt.title('Job Type Distribution')
plt.show()

# %%
# Count the number of applicants
applicant_count = df1['New Applicants'].value_counts()
print(applicant_count)
# Out:
# 200    151
# 1       43
# 2       18
# 26      18
# 3       17
#       ...
# 73       1
# 116      1
# 146      1
# 103      1
# 183      1
# Name: New Applicants, Length: 178, dtype: int64

# %%
# Plot the applicant counts
plt.bar(applicant_count.index, applicant_count.values)
plt.xlabel('New Applicants')
plt.ylabel('Count')
plt.title('Applicant Distribution')
plt.show()

# %%
# Count the number of industries
industry_count = df1['Industry'].value_counts()
print(industry_count)
# Out:
# Information Technology & Services    418
# Financial Services                   164
# Computer Software                    103
# Staffing & Recruiting                 30
# Human Resources                       28
#                                     ...
# Newspapers                             1
# Aviation & Aerospace                   1
# India                                  1
# Farming                                1
# Mental Health Care                     1
# Name: Industry, Length: 67, dtype: int64

# %%
# Plot the industry counts
plt.bar(industry_count.index, industry_count.values)
plt.xlabel('Industry')
plt.ylabel('Count')
plt.title('Industry Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
# Count the number of Invovlement
Invovlement_count = df1['Invovlement'].value_counts()
print(Invovlement_count)
# Out:
# Fulltime MidSenior level                         517
# Fulltime                                         263
# FulltimeEntry level                              195
# Fulltime Associate                                81
# Parttime                                          11
# FulltimeInternship                                 9
# Fulltime  Executive                                8
# ContractEntry level                                8
# Contract                                           7
# Temporary                                          5
# ContractMidSenior level                            5
# ParttimeInternship                                 4
# FulltimeDirector                                   4
# ContractAssociate                                  2
# ParttimeEntry level                                2
# InternshipInternship                               2
# InternshipMidSenior level                          1
# Ù??110,000/hr  Ù??125,000/hrContractAssociate      1
# ...

# %%
# Plot the Invovlement counts
plt.bar(Invovlement_count.index, Invovlement_count.values)
plt.xlabel('Invovlement')
plt.ylabel('Count')
plt.title('Invovlement Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
plt.pie(jobtype_count,labels=jobtype_count.index)
plt.show()

# %%
plt.pie(industry_count,labels=industry_count.index)
plt.show()

# %%
plt.pie(Invovlement_count,labels=Invovlement_count.index)
plt.show()

# %%
#descriptive statistics
pandas_profiling.ProfileReport(df1)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-04-24 14:16:04.824374&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# !pip install sweetviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 67.9 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv

# %%
# Analyze the data
sweet_report = sv.analyze(df1)
# Out:
# /usr/local/lib/python3.9/dist-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /usr/local/lib/python3.9/dist-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
#                                              |          | [  0%]   00:00 -> (? left)
# /usr/local/lib/python3.9/dist-packages/sweetviz/series_analyzer_text.py:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in to_process.source_counts["value_counts_without_nan"].iteritems():
# ...

# %%
# Generate report
sweet_report.show_html("report.html")
# Out:
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#Model FITTING

# %%
#k-means

# %%
df1.columns
# Out:
# Index(['Job_Name', 'Company', 'Location', 'State', 'Country', 'Job_type',
#        'Employees_Avg', 'Followers_Numbers', 'New Applicants', 'Industry',
#        'Invovlement'],
#       dtype='object')

# %%
#recommendation system

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Use one-hot encoding to handle categorical variables
jobs_df = pd.get_dummies(df1, columns=['Location', 'State', 'Industry','Invovlement'])
jobs_df
# Out:
#                                                Job_Name               Company  \
# 0     Client Technology: Platform Engineering, Senio...                    EY
# 1     Associate  Global Intelligence (Open Source Co...  JPMorgan Chase & Co.
# 2                         MTS Software Development Eng.                   AMD
# 3                           Tech Lead  Wifi Development     VVDN Technologies
# 4                         Senior Application Specialist      Leica Biosystems
# ...                                                 ...                   ...
# 1122                              AM AnalyticsANA007048               Genpact
# 1123                       Senior Data & API Consultant           Pluralsight
# 1124                                              Staff                 Bunge
# 1125      Software Performance Analyst (Cyber Security)            BlackBerry
# 1126                                  Team LeadBig Data              Infogain
#
# ...

# %%
num_cols = ['Employees_Avg', 'Followers_Numbers', 'New Applicants']

jobs_df[num_cols] = (jobs_df[num_cols] - jobs_df[num_cols].min()) / (jobs_df[num_cols].max() - jobs_df[num_cols].min())


jobs_df
# Out:
#                                                Job_Name               Company  \
# 0     Client Technology: Platform Engineering, Senio...                    EY
# 1     Associate  Global Intelligence (Open Source Co...  JPMorgan Chase & Co.
# 2                         MTS Software Development Eng.                   AMD
# 3                           Tech Lead  Wifi Development     VVDN Technologies
# 4                         Senior Application Specialist      Leica Biosystems
# ...                                                 ...                   ...
# 1122                              AM AnalyticsANA007048               Genpact
# 1123                       Senior Data & API Consultant           Pluralsight
# 1124                                              Staff                 Bunge
# 1125      Software Performance Analyst (Cyber Security)            BlackBerry
# 1126                                  Team LeadBig Data              Infogain
#
# ...

# %%
# Define the similarity metric
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(jobs_df['Job_Name'])

# %%
# Build the recommendation model
def get_recommendations(job_title, num_recommendations):
    job_idx = jobs_df[jobs_df['Job_Name'] == job_title].index[0]
    cosine_similarities = cosine_similarity(tfidf_matrix[job_idx], tfidf_matrix)
    similar_jobs_indices = cosine_similarities.argsort()[0][int(num_recommendations)-1:0:-1]
    return jobs_df.iloc[similar_jobs_indices]

# %%
# Test the recommendation system
recommendations = get_recommendations('Data Analyst', 5)
recommendations[['Job_Name', 'Company']]
# Out:
#                                               Job_Name  \
# 731                                    Technology Lead
# 730  Bus Process Delivery New AssociateQuery Manage...
# 729                                  Angular Developer
# 728  Senior Regional Technical Specialist Ù?? Marke...
#
#                                                Company
# 731                                   Broadridge India
# 730                                 Accenture in India
# 729                          Tata Consultancy Services
# 728  International Fund for Agricultural Developmen...

# %%
recommendations = get_recommendations('Data Science',5)
recommendations[['Job_Name', 'Company']]
# Out:
#                                               Job_Name  \
# 728  Senior Regional Technical Specialist Ù?? Marke...
# 727                   Guidewire Claim center developer
# 726                      Oracle Apps Technical Analyst
# 725                Transaction Processing AssociateKYC
#
#                                                Company
# 728  International Fund for Agricultural Developmen...
# 727                                     Aspire Systems
# 726                                            Emerson
# 725                                 Accenture in India

# %%
import pickle
with open('jobs_df.pkl', 'wb') as f1:
    pickle.dump(jobs_df, f1)

# %%
with open('jobs_df.pkl', 'rb') as f1:
    my_data = pickle.load(f1)

# %%
import pickle
with open('cosine_similarity.pkl', 'wb') as f:
    pickle.dump(cosine_similarity, f)

# %%
with open('cosine_similarity.pkl', 'rb') as f:
    cosine_similarities = pickle.load(f)
